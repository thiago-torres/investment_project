# %% [markdown]
# # Geral

# %%
from controller.api.mb_api import MercadoBitcoinPublicData
api = MercadoBitcoinPublicData()
api.get_networks_from_asset('USDT')
# Out:
# [{'coin': 'USDT', 'network': 'ethereum'}, {'coin': 'USDT', 'network': 'tron'}]

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from view.view_manager import ViewManager
view = ViewManager()
view.analyze_global_assets()
# Out:
# <style type="text/css">
# #T_f77f2_row0_col4 {
#   color: rgb(118, 136, 0);
# }
# #T_f77f2_row0_col5 {
#   color: rgb(65, 189, 0);
# }
# #T_f77f2_row0_col6 {
#   color: rgb(97, 157, 0);
# }
# </style>
# <table id="T_f77f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f77f2_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_f77f2_level0_col1" class="col_heading level0 col1" >EMA 1h</th>
#       <th id="T_f77f2_level0_col2" class="col_heading level0 col2" >EMA Day</th>
#       <th id="T_f77f2_level0_col3" class="col_heading level0 col3" >EMA Week</th>
#       <th id="T_f77f2_level0_col4" class="col_heading level0 col4" >RSI 1h</th>
#       <th id="T_f77f2_level0_col5" class="col_heading level0 col5" >RSI Day</th>
#       <th id="T_f77f2_level0_col6" class="col_heading level0 col6" >RSI Week</th>
#       <th id="T_f77f2_level0_col7" class="col_heading level0 col7" >Fib 23%</th>
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from view.view_manager import ViewManager
view = ViewManager()
display(view.analyze_personal_assets())
# Out:
#     id asset_type asset_name  current_quantity  average_price
# 0    1      stock   DASA3.SA             150.0           3.77
# 1    2      stock   JSLG3.SA             120.0           7.49
# 2    3      stock   CRPG5.SA              10.0          30.02
# 3    4      stock   UNIP6.SA              11.0          47.79
# 4    5      stock   TRPL4.SA              20.0          25.31
# 5    6      stock   RANI3.SA              97.0          10.04
# 6    7      stock   FESA4.SA              44.0          11.03
# 7    8      stock   CSAN3.SA              30.0          16.32
# 8    9      stock   VIIA3.SA              20.0          33.00
# 9   10        fii  HGLG11.SA               8.0         158.96
# 10  11        fii  IRDM11.SA              15.0          78.84
# 11  12        fii  MXRF11.SA             110.0          10.51
# 12  13        fii  KNCR11.SA              10.0          93.89
# 13  14        fii  RECR11.SA              10.0          86.17
# ...

# %%
from model.model_manager import ModelManager
obj = ModelManager()
display(obj.get_transactions(''))
obj.close()
# Out:
#     id  broker        date asset_type asset_name transaction_type  quantity  \
# 0    1  Nubank  2024-06-17      stock   DASA3.SA              buy     150.0
# 1    2  Nubank  2024-10-07      stock   JSLG3.SA              buy     120.0
# 2    3  Nubank  2024-04-04      stock   CRPG5.SA              buy      10.0
# 3    4  Nubank  2024-06-10      stock   UNIP6.SA              buy      11.0
# 4    5  Nubank  2024-02-27      stock   TRPL4.SA              buy      20.0
# 5    6  Nubank  2023-12-27      stock   RANI3.SA              buy      97.0
# 6    7  Nubank  2024-01-05      stock   FESA4.SA              buy      44.0
# 7    8  Nubank  2024-03-06      stock   CSAN3.SA              buy      30.0
# 8    9  Nubank  2023-08-07      stock   VIIA3.SA              buy      20.0
# 9   10  Nubank  2024-10-04        fii  HGLG11.SA              buy       8.0
# 10  11  Nubank  2024-10-04        fii  IRDM11.SA              buy      15.0
# ...

# %%
from model.model_manager import DbManager
obj = DbManager()
display(obj.insert_transaction(broker='teste',date='2024-04-04',asset_type='cripto',asset_name='btc',transaction_type='buy',quantity='1',unit_price='100',fee='0'))
obj.close()
# Out:
# None
