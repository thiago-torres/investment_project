# %% [markdown]
# # Geral

# %%
from controller.api.mb_api import MercadoBitcoinPublicData
api = MercadoBitcoinPublicData()
api.get_networks_from_asset('USDT')
# Out:
# [{'coin': 'USDT', 'network': 'ethereum'}, {'coin': 'USDT', 'network': 'tron'}]

# %%
from view.view_manager import ViewManager
view = ViewManager()
view.get_analysis_asset()
# Out:
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="">49.734</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="">51.248</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="">59.189</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="">74.612</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="">61.994</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="">51.796</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="background-color: green; color: white">41.598</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# g:\My Drive\investment_project\view\view_manager.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<span style="background-color: green; color: white">27.078</span>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, col] = f'<span style="{apply_color(row[col], value)}">{row[col]}</span>'
# <style type="text/css">
# #T_d8353_row0_col4, #T_d8353_row0_col5 {
#   color: rgb(94, 160, 0);
# }
# #T_d8353_row0_col6, #T_d8353_row28_col4 {
#   color: rgb(59, 195, 0);
# }
# #T_d8353_row1_col4 {
#   color: rgb(101, 153, 0);
# }
# #T_d8353_row1_col5 {
#   color: rgb(61, 193, 0);
# }
# #T_d8353_row1_col6 {
#   color: rgb(80, 174, 0);
# }
# #T_d8353_row2_col4 {
#   color: rgb(63, 191, 0);
# }
# #T_d8353_row2_col5, #T_d8353_row3_col6, #T_d8353_row51_col4 {
#   color: rgb(83, 171, 0);
# }
# #T_d8353_row2_col6 {
#   color: rgb(82, 172, 0);
# }
# #T_d8353_row3_col4, #T_d8353_row66_col4 {
#   color: rgb(92, 162, 0);
# }
# #T_d8353_row3_col5 {
#   color: rgb(87, 167, 0);
# }
# #T_d8353_row4_col4, #T_d8353_row24_col4, #T_d8353_row40_col5, #T_d8353_row45_col5 {
#   color: rgb(194, 60, 0);
# }
# #T_d8353_row4_col5, #T_d8353_row5_col5, #T_d8353_row19_col5 {
#   color: rgb(127, 127, 0);
# }
# #T_d8353_row4_col6, #T_d8353_row54_col4 {
#   color: rgb(88, 166, 0);
# }
# #T_d8353_row5_col4, #T_d8353_row9_col4 {
#   color: rgb(112, 142, 0);
# }
# #T_d8353_row5_col6, #T_d8353_row26_col5 {
#   color: rgb(93, 161, 0);
# }
# #T_d8353_row6_col4, #T_d8353_row39_col4 {
#   color: rgb(110, 144, 0);
# }
# #T_d8353_row6_col5, #T_d8353_row27_col4 {
#   color: rgb(113, 141, 0);
# }
# #T_d8353_row6_col6, #T_d8353_row68_col4 {
#   color: rgb(97, 157, 0);
# }
# #T_d8353_row7_col4, #T_d8353_row55_col6 {
#   color: rgb(187, 67, 0);
# }
# #T_d8353_row7_col5, #T_d8353_row19_col6, #T_d8353_row41_col4 {
#   color: rgb(138, 116, 0);
# }
# #T_d8353_row7_col6, #T_d8353_row13_col4, #T_d8353_row61_col4 {
#   color: rgb(107, 147, 0);
# }
# #T_d8353_row8_col4, #T_d8353_row10_col6 {
#   color: rgb(121, 133, 0);
# }
# #T_d8353_row8_col5, #T_d8353_row18_col5, #T_d8353_row22_col6, #T_d8353_row23_col6, #T_d8353_row42_col4 {
#   color: rgb(146, 108, 0);
# }
# #T_d8353_row8_col6 {
#   color: rgb(108, 146, 0);
# }
# #T_d8353_row9_col5 {
#   color: rgb(120, 134, 0);
# }
# #T_d8353_row9_col6, #T_d8353_row17_col4, #T_d8353_row20_col4 {
#   color: rgb(116, 138, 0);
# }
# #T_d8353_row10_col4 {
#   color: rgb(39, 215, 0);
# }
# #T_d8353_row10_col5, #T_d8353_row17_col5 {
#   color: rgb(132, 122, 0);
# }
# #T_d8353_row11_col4, #T_d8353_row38_col4 {
#   color: rgb(73, 181, 0);
# }
# #T_d8353_row11_col5 {
#   color: rgb(104, 150, 0);
# }
# #T_d8353_row11_col6, #T_d8353_row14_col5 {
#   color: rgb(123, 131, 0);
# }
# #T_d8353_row12_col4, #T_d8353_row23_col5, #T_d8353_row27_col5, #T_d8353_row32_col5 {
#   color: rgb(165, 89, 0);
# }
# #T_d8353_row12_col5, #T_d8353_row47_col6, #T_d8353_row48_col6 {
#   color: rgb(176, 78, 0);
# }
# #T_d8353_row12_col6 {
#   color: rgb(124, 130, 0);
# }
# #T_d8353_row13_col5, #T_d8353_row15_col5 {
#   color: rgb(157, 97, 0);
# }
# #T_d8353_row13_col6, #T_d8353_row25_col4 {
#   color: rgb(128, 126, 0);
# }
# #T_d8353_row14_col4 {
#   color: rgb(5, 249, 0);
# }
# #T_d8353_row14_col6, #T_d8353_row32_col4, #T_d8353_row46_col5 {
#   color: rgb(129, 125, 0);
# }
# #T_d8353_row15_col4, #T_d8353_row51_col5 {
#   color: rgb(182, 72, 0);
# }
# #T_d8353_row15_col6, #T_d8353_row16_col6, #T_d8353_row57_col4 {
#   color: rgb(134, 120, 0);
# }
# #T_d8353_row16_col4, #T_d8353_row18_col6 {
#   color: rgb(136, 118, 0);
# }
# #T_d8353_row16_col5, #T_d8353_row49_col6 {
#   color: rgb(178, 76, 0);
# }
# #T_d8353_row17_col6 {
#   color: rgb(135, 119, 0);
# }
# #T_d8353_row18_col4, #T_d8353_row36_col6 {
#   color: rgb(163, 91, 0);
# }
# #T_d8353_row19_col4 {
#   color: rgb(51, 203, 0);
# }
# #T_d8353_row20_col5, #T_d8353_row39_col6, #T_d8353_row55_col4, #T_d8353_row58_col4 {
#   color: rgb(167, 87, 0);
# }
# #T_d8353_row20_col6 {
#   color: rgb(141, 113, 0);
# }
# #T_d8353_row21_col4 {
#   color: rgb(137, 117, 0);
# }
# #T_d8353_row21_col5, #T_d8353_row37_col5, #T_d8353_row42_col6, #T_d8353_row43_col5, #T_d8353_row43_col6 {
#   color: rgb(170, 84, 0);
# }
# #T_d8353_row21_col6, #T_d8353_row43_col4 {
#   color: rgb(142, 112, 0);
# }
# #T_d8353_row22_col4 {
#   color: rgb(45, 209, 0);
# }
# #T_d8353_row22_col5, #T_d8353_row33_col5 {
#   color: rgb(159, 95, 0);
# }
# #T_d8353_row23_col4 {
#   color: rgb(109, 145, 0);
# }
# #T_d8353_row24_col5, #T_d8353_row35_col4, #T_d8353_row50_col6, #T_d8353_row51_col6, #T_d8353_row52_col6 {
#   color: rgb(179, 75, 0);
# }
# #T_d8353_row24_col6 {
#   color: rgb(147, 107, 0);
# }
# #T_d8353_row25_col5 {
#   color: rgb(188, 66, 0);
# }
# #T_d8353_row25_col6 {
#   color: rgb(148, 106, 0);
# }
# #T_d8353_row26_col4 {
#   color: green;
# }
# #T_d8353_row26_col6 {
#   color: rgb(149, 105, 0);
# }
# #T_d8353_row27_col6, #T_d8353_row30_col5, #T_d8353_row34_col5, #T_d8353_row71_col4 {
#   color: rgb(150, 104, 0);
# }
# #T_d8353_row28_col5 {
#   color: rgb(126, 128, 0);
# }
# #T_d8353_row28_col6 {
#   color: rgb(151, 103, 0);
# }
# #T_d8353_row29_col4 {
#   color: rgb(234, 20, 0);
# }
# #T_d8353_row29_col5, #T_d8353_row42_col5 {
#   color: rgb(198, 56, 0);
# }
# #T_d8353_row29_col6, #T_d8353_row44_col5 {
#   color: rgb(152, 102, 0);
# }
# #T_d8353_row30_col4 {
#   color: rgb(17, 237, 0);
# }
# #T_d8353_row30_col6, #T_d8353_row56_col4 {
#   color: rgb(155, 99, 0);
# }
# #T_d8353_row31_col4 {
#   color: rgb(144, 110, 0);
# }
# #T_d8353_row31_col5 {
#   color: rgb(184, 70, 0);
# }
# #T_d8353_row31_col6 {
#   color: rgb(156, 98, 0);
# }
# #T_d8353_row32_col6 {
#   color: rgb(160, 94, 0);
# }
# #T_d8353_row33_col4 {
#   color: rgb(96, 158, 0);
# }
# #T_d8353_row33_col6, #T_d8353_row34_col6 {
#   color: rgb(161, 93, 0);
# }
# #T_d8353_row34_col4 {
#   color: rgb(118, 136, 0);
# }
# #T_d8353_row35_col5, #T_d8353_row70_col4 {
#   color: rgb(175, 79, 0);
# }
# #T_d8353_row35_col6 {
#   color: rgb(162, 92, 0);
# }
# #T_d8353_row36_col4 {
#   color: rgb(232, 22, 0);
# }
# #T_d8353_row36_col5, #T_d8353_row38_col5 {
#   color: rgb(205, 49, 0);
# }
# #T_d8353_row37_col4 {
#   color: rgb(100, 154, 0);
# }
# #T_d8353_row37_col6, #T_d8353_row38_col6, #T_d8353_row69_col4 {
#   color: rgb(166, 88, 0);
# }
# #T_d8353_row39_col5, #T_d8353_row56_col6 {
#   color: rgb(190, 64, 0);
# }
# #T_d8353_row40_col4, #T_d8353_row53_col6 {
#   color: rgb(183, 71, 0);
# }
# #T_d8353_row40_col6, #T_d8353_row60_col4 {
#   color: rgb(168, 86, 0);
# }
# #T_d8353_row41_col5, #T_d8353_row44_col6 {
#   color: rgb(172, 82, 0);
# }
# #T_d8353_row41_col6, #T_d8353_row50_col5 {
#   color: rgb(169, 85, 0);
# }
# #T_d8353_row44_col4 {
#   color: rgb(102, 152, 0);
# }
# #T_d8353_row45_col4 {
#   color: rgb(143, 111, 0);
# }
# #T_d8353_row45_col6, #T_d8353_row46_col6, #T_d8353_row52_col5 {
#   color: rgb(174, 80, 0);
# }
# #T_d8353_row46_col4 {
#   color: rgb(70, 184, 0);
# }
# #T_d8353_row47_col4, #T_d8353_row62_col4 {
#   color: rgb(140, 114, 0);
# }
# #T_d8353_row47_col5 {
#   color: rgb(213, 41, 0);
# }
# #T_d8353_row48_col4 {
#   color: rgb(42, 212, 0);
# }
# #T_d8353_row48_col5, #T_d8353_row66_col5 {
#   color: rgb(203, 51, 0);
# }
# #T_d8353_row49_col4 {
#   color: rgb(171, 83, 0);
# }
# #T_d8353_row49_col5, #T_d8353_row56_col5, #T_d8353_row64_col6 {
#   color: rgb(206, 48, 0);
# }
# #T_d8353_row50_col4 {
#   color: rgb(34, 220, 0);
# }
# #T_d8353_row52_col4 {
#   color: rgb(86, 168, 0);
# }
# #T_d8353_row53_col4 {
#   color: rgb(130, 124, 0);
# }
# #T_d8353_row53_col5, #T_d8353_row63_col6 {
#   color: rgb(202, 52, 0);
# }
# #T_d8353_row54_col5, #T_d8353_row67_col4 {
#   color: rgb(180, 74, 0);
# }
# #T_d8353_row54_col6 {
#   color: rgb(186, 68, 0);
# }
# #T_d8353_row55_col5, #T_d8353_row68_col6 {
#   color: rgb(222, 32, 0);
# }
# #T_d8353_row57_col5, #T_d8353_row64_col5, #T_d8353_row70_col6 {
#   color: rgb(244, 10, 0);
# }
# #T_d8353_row57_col6, #T_d8353_row67_col5 {
#   color: rgb(192, 62, 0);
# }
# #T_d8353_row58_col5 {
#   color: rgb(243, 11, 0);
# }
# #T_d8353_row58_col6 {
#   color: rgb(196, 58, 0);
# }
# #T_d8353_row59_col4 {
#   color: rgb(77, 177, 0);
# }
# #T_d8353_row59_col5 {
#   color: rgb(209, 45, 0);
# }
# #T_d8353_row59_col6 {
#   color: rgb(197, 57, 0);
# }
# #T_d8353_row60_col5, #T_d8353_row65_col5 {
#   color: rgb(204, 50, 0);
# }
# #T_d8353_row60_col6 {
#   color: rgb(199, 55, 0);
# }
# #T_d8353_row61_col5, #T_d8353_row62_col6 {
#   color: rgb(201, 53, 0);
# }
# #T_d8353_row61_col6 {
#   color: rgb(200, 54, 0);
# }
# #T_d8353_row62_col5, #T_d8353_row71_col5, #T_d8353_row72_col6 {
#   color: red;
# }
# #T_d8353_row63_col4 {
#   color: rgb(58, 196, 0);
# }
# #T_d8353_row63_col5 {
#   color: rgb(233, 21, 0);
# }
# #T_d8353_row64_col4 {
#   color: rgb(195, 59, 0);
# }
# #T_d8353_row65_col4 {
#   color: rgb(95, 159, 0);
# }
# #T_d8353_row65_col6 {
#   color: rgb(208, 46, 0);
# }
# #T_d8353_row66_col6 {
#   color: rgb(219, 35, 0);
# }
# #T_d8353_row67_col6, #T_d8353_row72_col4 {
#   color: rgb(220, 34, 0);
# }
# #T_d8353
