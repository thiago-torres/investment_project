# %% [markdown]
# # Geral

# %%
from controller.api.mb_api import MercadoBitcoinPublicData
api = MercadoBitcoinPublicData()
api.get_networks_from_asset('USDT')

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from view.view_manager import ViewManager
view = ViewManager()
view.analyze_global_assets('1')

# %% [markdown]
# # teste MB

# %%
from controller.api.mb_api import MercadoBitcoinPublicData

api = MercadoBitcoinPublicData()

symbols = api.get_symbols()

print(symbols)

# %%
for n in symbols['symbol']:
    print(n)

# %%
import time
import pandas
start_timestamp = int(time.time()) - (86400 * 30)  # Timestamp de 30 dias atrás

# Chamando o método com um timestamp válido
download = api.get_candles("BTC-BRL", "1d", start_timestamp)
df = pandas.DataFrame(download)

print(df)

# %% [markdown]
# # db

# %%
from model.model_manager import ModelManager
obj = ModelManager()
display(obj.get_transactions(''))
# Out:
#     id corretora        data    tipo  ticker transacao      cotas  \
# 0    1    Nubank  2024-06-17   ações   DASA3       buy  150.00000
# 1    2    Nubank  2024-10-07   ações   JSLG3       buy  120.00000
# 2    3    Nubank  2024-04-04   ações   CRPG5       buy   10.00000
# 3    4    Nubank  2024-06-10   ações   UNIP6       buy   11.00000
# 4    5    Nubank  2024-02-27   ações   TRPL4       buy   20.00000
# 5    6    Nubank  2023-12-27   ações   RANI3       buy   97.00000
# 6    7    Nubank  2024-01-05   ações   FESA4       buy   44.00000
# 7    8    Nubank  2024-03-06   ações   CSAN3       buy   30.00000
# 8    9    Nubank  2023-08-07   ações   BHIA3       buy   20.00000
# 9   10    Nubank  2024-10-04     FII  HGLG11       buy    8.00000
# 10  11    Nubank  2024-10-04     FII  IRDM11       buy   15.00000
# 11  12    Nubank  2024-10-04     FII  MXRF11       buy  110.00000
# 12  13    Nubank  2024-10-04     FII  KNCR11       buy   10.00000
# 13  14    Nubank  2024-10-04     FII  RECR11       buy   10.00000
# 14  15    Nubank  2024-10-04     FII  CPTS11       buy  100.00000
# 15  16    Nubank  2024-10-04     FII  FGAA11       buy   95.00000
# 16  17    Nubank  2024-10-04     FII  ALZM11       buy   60.00000
# 17  18    Nubank  2024-10-04     FII  XPCA11       buy   55.00000
# 18  19    Nubank  2024-10-04     FII  BTLG11       buy    3.00000
# 19  20    Nubank  2024-10-04     FII  KNCA11       buy    3.00000
# 20  21    Nubank  2024-10-04     FII  MCCI11       buy    2.00000
# 21  22    Nubank  2024-10-04     FII  TRXF11       buy    4.00000
# 22  23    Nubank  2024-10-04     FII  HFOF11       buy    7.00000
# 23  25        MB  2024-10-20  cripto     MKR       buy    0.14211
#
#     preco_unitario      taxa
# 0             3.77  0.170000
# 1             7.49  0.300000
# 2            30.02  0.090000
# 3            47.79  0.160000
# 4            25.31  0.150000
# 5            10.04  0.290000
# 6            11.03  0.150000
# 7            16.32  0.150000
# 8            33.00  0.200000
# 9           158.96  0.380000
# 10           78.84  0.350000
# 11           10.51  0.350000
# 12           93.89  0.280000
# 13           86.17  0.260000
# 14            7.56  0.230000
# 15            8.92  0.250000
# 16            8.57  0.150000
# 17            8.91  0.150000
# 18          100.88  0.090000
# 19          100.21  0.090000
# 20           92.01  0.060000
# 21          108.19  0.130000
# 22           64.89  0.140000
# 23         6987.50  0.001002

# %%
from model.model_manager import ModelManager
obj = ModelManager()
# obj.insert_transaction(corretora="MB",data="2024-10-20",tipo="cripto",ticker="BTC",transacao="buy",cotas=0.14211,preco_unitario=300000.50,taxa=0.001002)

# %%
from model.model_manager import ModelManager
obj = ModelManager()
display(obj.get_assets())

# %%
# Teste manual
manager = ModelManager()
# manager.update_or_insert_asset('cripto', 'MKR', 0.5, 5000)
