# %% [markdown]
# # Geral

# %%
from controller.api.mb_api import MercadoBitcoinPublicData
api = MercadoBitcoinPublicData()
api.get_networks_from_asset('USDT')
# Out:
# [{'coin': 'USDT', 'network': 'ethereum'}, {'coin': 'USDT', 'network': 'tron'}]

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from view.view_manager import ViewManager
view = ViewManager()
view.get_analysis_global_assets()
# Out:
# <style type="text/css">
# #T_eedbb_row0_col4, #T_eedbb_row36_col4 {
#   color: rgb(96, 158, 0);
# }
# #T_eedbb_row0_col5, #T_eedbb_row3_col4 {
#   color: green;
# }
# #T_eedbb_row0_col6 {
#   color: rgb(37, 217, 0);
# }
# #T_eedbb_row1_col4, #T_eedbb_row33_col4 {
#   color: rgb(109, 145, 0);
# }
# #T_eedbb_row1_col5, #T_eedbb_row4_col6, #T_eedbb_row9_col5 {
#   color: rgb(54, 200, 0);
# }
# #T_eedbb_row1_col6, #T_eedbb_row24_col5 {
#   color: rgb(43, 211, 0);
# }
# #T_eedbb_row2_col4, #T_eedbb_row24_col6, #T_eedbb_row25_col6 {
#   color: rgb(106, 148, 0);
# }
# #T_eedbb_row2_col5 {
#   color: rgb(34, 220, 0);
# }
# #T_eedbb_row2_col6, #T_eedbb_row3_col6 {
#   color: rgb(50, 204, 0);
# }
# #T_eedbb_row3_col5, #T_eedbb_row11_col5 {
#   color: rgb(3, 251, 0);
# }
# #T_eedbb_row4_col4, #T_eedbb_row8_col6, #T_eedbb_row27_col4 {
#   color: rgb(70, 184, 0);
# }
# #T_eedbb_row4_col5 {
#   color: rgb(28, 226, 0);
# }
# #T_eedbb_row5_col4 {
#   color: rgb(61, 193, 0);
# }
# #T_eedbb_row5_col5 {
#   color: rgb(10, 244, 0);
# }
# #T_eedbb_row5_col6, #T_eedbb_row6_col5 {
#   color: rgb(55, 199, 0);
# }
# #T_eedbb_row6_col4, #T_eedbb_row7_col4 {
#   color: rgb(100, 154, 0);
# }
# #T_eedbb_row6_col6 {
#   color: rgb(58, 196, 0);
# }
# #T_eedbb_row7_col5 {
#   color: rgb(7, 247, 0);
# }
# #T_eedbb_row7_col6, #T_eedbb_row14_col5 {
#   color: rgb(64, 190, 0);
# }
# #T_eedbb_row8_col4, #T_eedbb_row23_col6 {
#   color: rgb(105, 149, 0);
# }
# #T_eedbb_row8_col5, #T_eedbb_row15_col6, #T_eedbb_row16_col6, #T_eedbb_row38_col5 {
#   color: rgb(84, 170, 0);
# }
# #T_eedbb_row9_col4 {
#   color: rgb(134, 120, 0);
# }
# #T_eedbb_row9_col6 {
#   color: rgb(72, 182, 0);
# }
# #T_eedbb_row10_col4 {
#   color: rgb(132, 122, 0);
# }
# #T_eedbb_row10_col5 {
#   color: rgb(99, 155, 0);
# }
# #T_eedbb_row10_col6 {
#   color: rgb(73, 181, 0);
# }
# #T_eedbb_row11_col4 {
#   color: rgb(78, 176, 0);
# }
# #T_eedbb_row11_col6 {
#   color: rgb(75, 179, 0);
# }
# #T_eedbb_row12_col4 {
#   color: rgb(63, 191, 0);
# }
# #T_eedbb_row12_col5 {
#   color: rgb(67, 187, 0);
# }
# #T_eedbb_row12_col6, #T_eedbb_row13_col6, #T_eedbb_row29_col5 {
#   color: rgb(81, 173, 0);
# }
# #T_eedbb_row13_col4 {
#   color: rgb(65, 189, 0);
# }
# #T_eedbb_row13_col5 {
#   color: rgb(31, 223, 0);
# }
# #T_eedbb_row14_col4, #T_eedbb_row19_col5 {
#   color: rgb(71, 183, 0);
# }
# #T_eedbb_row14_col6, #T_eedbb_row30_col5 {
#   color: rgb(82, 172, 0);
# }
# #T_eedbb_row15_col4 {
#   color: rgb(151, 103, 0);
# }
# #T_eedbb_row15_col5, #T_eedbb_row38_col4 {
#   color: rgb(94, 160, 0);
# }
# #T_eedbb_row16_col4, #T_eedbb_row38_col6 {
#   color: rgb(146, 108, 0);
# }
# #T_eedbb_row16_col5, #T_eedbb_row17_col5 {
#   color: rgb(83, 171, 0);
# }
# #T_eedbb_row17_col4 {
#   color: rgb(160, 94, 0);
# }
# #T_eedbb_row17_col6 {
#   color: rgb(86, 168, 0);
# }
# #T_eedbb_row18_col4 {
#   color: rgb(29, 225, 0);
# }
# #T_eedbb_row18_col5 {
#   color: rgb(5, 249, 0);
# }
# #T_eedbb_row18_col6, #T_eedbb_row19_col6, #T_eedbb_row27_col5, #T_eedbb_row41_col4 {
#   color: rgb(92, 162, 0);
# }
# #T_eedbb_row19_col4 {
#   color: rgb(172, 82, 0);
# }
# #T_eedbb_row20_col4, #T_eedbb_row33_col6, #T_eedbb_row35_col4 {
#   color: rgb(130, 124, 0);
# }
# #T_eedbb_row20_col5, #T_eedbb_row30_col4 {
#   color: rgb(119, 135, 0);
# }
# #T_eedbb_row20_col6, #T_eedbb_row25_col5 {
#   color: rgb(93, 161, 0);
# }
# #T_eedbb_row21_col4, #T_eedbb_row28_col6 {
#   color: rgb(114, 140, 0);
# }
# #T_eedbb_row21_col5 {
#   color: rgb(79, 175, 0);
# }
# #T_eedbb_row21_col6, #T_eedbb_row22_col5 {
#   color: rgb(98, 156, 0);
# }
# #T_eedbb_row22_col4, #T_eedbb_row23_col4, #T_eedbb_row36_col6 {
#   color: rgb(140, 114, 0);
# }
# #T_eedbb_row22_col6 {
#   color: rgb(103, 151, 0);
# }
# #T_eedbb_row23_col5 {
#   color: rgb(90, 164, 0);
# }
# #T_eedbb_row24_col4 {
#   color: rgb(9, 245, 0);
# }
# #T_eedbb_row25_col4, #T_eedbb_row41_col6 {
#   color: rgb(155, 99, 0);
# }
# #T_eedbb_row26_col4 {
#   color: rgb(87, 167, 0);
# }
# #T_eedbb_row26_col5 {
#   color: rgb(57, 197, 0);
# }
# #T_eedbb_row26_col6 {
#   color: rgb(110, 144, 0);
# }
# #T_eedbb_row27_col6, #T_eedbb_row34_col5, #T_eedbb_row35_col5 {
#   color: rgb(113, 141, 0);
# }
# #T_eedbb_row28_col4 {
#   color: rgb(121, 133, 0);
# }
# #T_eedbb_row28_col5, #T_eedbb_row44_col4 {
#   color: rgb(56, 198, 0);
# }
# #T_eedbb_row29_col4, #T_eedbb_row40_col6 {
#   color: rgb(148, 106, 0);
# }
# #T_eedbb_row29_col6 {
#   color: rgb(115, 139, 0);
# }
# #T_eedbb_row30_col6 {
#   color: rgb(118, 136, 0);
# }
# #T_eedbb_row31_col4, #T_eedbb_row31_col6, #T_eedbb_row32_col6 {
#   color: rgb(120, 134, 0);
# }
# #T_eedbb_row31_col5 {
#   color: rgb(116, 138, 0);
# }
# #T_eedbb_row32_col4 {
#   color: rgb(152, 102, 0);
# }
# #T_eedbb_row32_col5 {
#   color: rgb(122, 132, 0);
# }
# #T_eedbb_row33_col5 {
#   color: rgb(62, 192, 0);
# }
# #T_eedbb_row34_col4, #T_eedbb_row39_col5, #T_eedbb_row43_col5 {
#   color: rgb(127, 127, 0);
# }
# #T_eedbb_row34_col6 {
#   color: rgb(135, 119, 0);
# }
# #T_eedbb_row35_col6 {
#   color: rgb(138, 116, 0);
# }
# #T_eedbb_row36_col5 {
#   color: rgb(101, 153, 0);
# }
# #T_eedbb_row37_col4 {
#   color: rgb(102, 152, 0);
# }
# #T_eedbb_row37_col5, #T_eedbb_row43_col4 {
#   color: rgb(126, 128, 0);
# }
# #T_eedbb_row37_col6 {
#   color: rgb(144, 110, 0);
# }
# #T_eedbb_row39_col4 {
#   color: rgb(107, 147, 0);
# }
# #T_eedbb_row39_col6 {
#   color: rgb(147, 107, 0);
# }
# #T_eedbb_row40_col4, #T_eedbb_row44_col6 {
#   color: rgb(190, 64, 0);
# }
# #T_eedbb_row40_col5 {
#   color: rgb(166, 88, 0);
# }
# #T_eedbb_row41_col5 {
#   color: rgb(129, 125, 0);
# }
# #T_eedbb_row42_col4 {
#   color: rgb(15, 239, 0);
# }
# #T_eedbb_row42_col5 {
#   color: rgb(89, 165, 0);
# }
# #T_eedbb_row42_col6 {
#   color: rgb(171, 83, 0);
# }
# #T_eedbb_row43_col6 {
#   color: rgb(182, 72, 0);
# }
# #T_eedbb_row44_col5 {
#   color: rgb(112, 142, 0);
# }
# #T_eedbb_row45_col4 {
#   color: rgb(136, 118, 0);
# }
# #T_eedbb_row45_col5 {
#   color: rgb(153, 101, 0);
# }
# #T_eedbb_row45_col6 {
#   color: rgb(216, 38, 0);
# }
# </style>
# <table id="T_eedbb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eedbb_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_eedbb_level0_col1" class="col_heading level0 col1" >EMA 1h</th>
#       <th id="T_eedbb_level0_col2" class="col_heading level0 col2" >EMA Day</th>
#       <th id="T_eedbb_level0_col3" class="col_heading level0 col3" >EMA Week</th>
#       <th id="T_eedbb_level0_col4" class="col_heading level0 col4" >RSI 1h</th>
#       <th id="T_eedbb_level0_col5" class="col_heading level0 col5" >RSI Day</th>
#       <th id="T_eedbb_level0_col6" class="col_heading level0 col6" >RSI Week</th>
#       <th id="T_eedbb_level0_col7" class="col_heading level0 col7" >Fib 23%</th>
#       <th id="T_eedbb_level0_col8" class="col_heading level0 col8" >Fib 38%</th>
#       <th id="T_eedbb_level0_col9" class="col_heading level0 col9" >Fib 50%</th>
#       <th id="T_eedbb_level0_col10" class="col_heading level0 col10" >Fib 61%</th>
#       <th id="T_eedbb_level0_col11" class="col_heading level0 col11" >Fib 78%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eedbb_level0_row0" class="row_heading level0 row0" ><a href="https://br.tradingview.com/chart/JKfvODlT/?symbol=BMFBOVESPA%3AHFOF11" target="_blank">HFOF11</a></th>
#       <td id="T_eedbb_row0_col0" class="data row0 col0" >64.550000</td>
#       <td id="T_eedbb_row0_col1" class="data row0 col1" ><span style="">65.954</span></td>
#       <td id="T_eedbb_row0_col2" class="data row0 col2" ><span style="">68.078</span></td>
#       <td id="T_eedbb_row0_col3" class="data row0 col3" ><span style="">68.125</span></td>
#       <td id="T_eedbb_row0_col4" class="data row0 col4" >42.661000</td>
#       <td id="T_eedbb_row0_col5" class="data row0 col5" >16.540000</td>
#       <td id="T_eedbb_row0_col6" class="data row0 col6" >28.743000</td>
#       <td id="T_eedbb_row0_col7" class="data row0 col7" ><span style="">87.311</span></td>
#       <td id="T_eedbb_row0_col8" class="data row0 col8" ><span style="">80.958</span></td>
#       <td id="T_eedbb_row0_col9" class="data row0 col9" ><span style="">75.823</span></td>
#       <td id="T_eedbb_row0_col10" class="data row0 col10" ><span style="">70.688</span></td>
#       <td id="T_eedbb_row0_col11" class="data row0 col11" ><span style="background-color: green; color: white">63.377</span></td>
#     </tr>
#     <tr>
#       <th id="T_eedbb_level0_row1" class="row_heading level0 row1" ><a href="https://br.tradingview.com/chart/JKf

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from view.view_manager import ViewManager
view = ViewManager()
view.get_analysis_my_assets()

# %%
from model.database_manager import DbManager
obj = DbManager()
display(obj.get_transactions('DASA'))
obj.close()
# Out:
#    id  broker        date asset_type asset_name transaction_type  quantity  \
# 0   1  Nubank  2024-06-17      stock   DASA3.SA              buy     150.0
#
#    unit_price   fee
# 0        3.77  0.17
